# %%
import argparse
from pathlib import Path
import sys
 
sys.path.append("/workspace/data_extraction")
import extract_data
 
args = argparse.Namespace(
    input_dir=Path("../data_ensembl"),
    output_dir=Path("../data"),
    input_file=["3-187668812-187670494.txt"],          # o ["3-187668812-187670494.txt"]
    flank_size=1000
)
 
extract_data.run(args)
# Out:
# Processed files: 1
# 0
